# %%
import pandas as pd
import numpy as np
import datetime

# %%
data = pd.read_csv('dataset/all_data.csv')
data
# Out:
# D:\miniconda\envs\pytorch\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (1,2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              company_id                port_id polution_id               date  \
# 0        17280000089583  64000000000600100000       w00000  1/1/2020 00:00:00
# 1        17280000089583  64000000000600100000       w00000  2/1/2020 00:00:00
# 2        17280000089583  64000000000600100000       w00000  3/1/2020 00:00:00
# 3        17280000089583  64000000000600100000       w00000  4/1/2020 00:00:00
# 4        17280000089583  64000000000600100000       w00000  5/1/2020 00:00:00
# ...                 ...                    ...         ...                ...
# 1048571           89421                  89421         NaN                NaN
# 1048572           89421                  89421         NaN                NaN
# ...

# %%
# data = data.astype({'company_id':str, 'port_id':str, 'polution_id':str})
data['company_id'] = data['company_id'].astype('string')
data['port_id'] = data['port_id'].astype('string')
data['polution_id'] = data['polution_id'].astype('string')
data['date'] = pd.to_datetime(data['date'], format='%d/%m/%Y %H:%M:%S')

print(data['port_id'] == "64000000000600100000 ")
data.dtypes
data = data.fillna({'concentration': 0, 'amount': 0})

print(data.loc[0, 'port_id'])
data.dtypes
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048571    False
# 1048572    False
# 1048573    False
# 1048574    False
# 1048575    False
# Name: port_id, Length: 1048576, dtype: boolean
# 64000000000600100000
# company_id               string
# port_id                  string
# polution_id              string
# date             datetime64[ns]
# concentration           float64
# amount                  float64
# dtype: object

# %%
port_id = '64000000000600100000'
polution_id = 'w00000'
date_s = '1/1/2020'
data_e = '5/1/2020'
# data_port = data.loc[data['port_id' == port_id]]
# data_port = data[data['port_id'] == '64000000000600100000 ']
data_port = data[data['port_id'].str.contains('64000000000600100000')]
data_port
# Out:
#           company_id                port_id polution_id       date  \
# 0     17280000089583  64000000000600100000       w00000 2020-01-01
# 1     17280000089583  64000000000600100000       w00000 2020-01-02
# 2     17280000089583  64000000000600100000       w00000 2020-01-03
# 3     17280000089583  64000000000600100000       w00000 2020-01-04
# 4     17280000089583  64000000000600100000       w00000 2020-01-05
# ...              ...                    ...         ...        ...
# 4372  17280000089583  64000000000600100000       w21011 2021-11-25
# 4373  17280000089583  64000000000600100000       w21011 2021-11-26
# 4374  17280000089583  64000000000600100000       w21011 2021-11-27
# 4375  17280000089583  64000000000600100000       w21011 2021-11-28
# 4376  17280000089583  64000000000600100000       w21011 2021-11-29
#
#       concentration    amount
# 0            66.250   870.000
# 1            73.180  1758.000
# 2            79.950  1918.000
# 3            69.910  1678.000
# ...

# %%
data_time = data_port.loc[(data_port['date'] >= pd.to_datetime('1/1/2020', format='%d/%m/%Y')) &
                          (data_port['date'] <= pd.to_datetime('5/1/2020',format='%d/%m/%Y'))]
data_time
# Out:
#           company_id                port_id polution_id       date  \
# 0     17280000089583  64000000000600100000       w00000 2020-01-01
# 1     17280000089583  64000000000600100000       w00000 2020-01-02
# 2     17280000089583  64000000000600100000       w00000 2020-01-03
# 3     17280000089583  64000000000600100000       w00000 2020-01-04
# 4     17280000089583  64000000000600100000       w00000 2020-01-05
# 675   17280000089583  64000000000600100000       w01001 2020-01-01
# 676   17280000089583  64000000000600100000       w01001 2020-01-02
# 677   17280000089583  64000000000600100000       w01001 2020-01-03
# 678   17280000089583  64000000000600100000       w01001 2020-01-04
# 679   17280000089583  64000000000600100000       w01001 2020-01-05
# 1677  17280000089583  64000000000600100000       w01018 2020-01-01
# 1678  17280000089583  64000000000600100000       w01018 2020-01-02
# 1679  17280000089583  64000000000600100000       w01018 2020-01-03
# ...

# %%
data_polution_id = data_port[data_port['polution_id'] == 'w00000']
data_polution_id
